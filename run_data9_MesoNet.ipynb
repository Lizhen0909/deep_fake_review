# %%
import os,sys

# %%
files1=!find  `pwd`/data/data9/ -name \*.jpg 
files2=!find `pwd`/data/data9/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 74337

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg']

# %%
NAME='MesoNet'

# %%
with open('/tmp/inputlist_{}'.format(NAME), 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_$NAME
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg

# %%
# !mkdir -p results/$NAME

# %%
# %%time
# !cd $NAME && \
PYTHONPATH=. conda run -n $NAME \
python  ../run_MesoNet_example.py \
-i /tmp/inputlist_$NAME \
--output ../results/$NAME/data9.txt
# Out:
# num of images= 74337
# loaded model
# Found 74337 validated image filenames belonging to 2 classes.
# begin predit
# processed 74337 images
#
# WARNING:tensorflow:From /global/home/users/lizhen/.conda/envs/MesoNet/lib/python3.5/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /global/home/users/lizhen/.conda/envs/MesoNet/lib/python3.5/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /global/home/users/lizhen/.conda/envs/MesoNet/lib/python3.5/site-packages/tensorflow/python/keras/utils/losses_utils.py:170: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 2021-08-13 17:29:21.648271: I tensorflow/core/platform/cpu_feature_guard.cc:141] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2021-08-13 17:29:21.983995: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2294780000 Hz
# 2021-08-13 17:29:22.009096: I tensorflow/compiler/xla/service/service.cc:150] XLA service 0x556ae80 executing computations on platform Host. Devices:
# 2021-08-13 17:29:22.009140: I tensorflow/compiler/xla/service/service.cc:158]   StreamExecutor device (0): <undefined>, <undefined>
# 100%|#########9| 580/581 [12:05<00:01,  1.25s/it]
# CPU times: user 13.3 s, sys: 2.23 s, total: 15.5 s
# Wall time: 13min 40s

# %%
# !wc -l  results/$NAME/data9.txt
# Out:
# 74337 results/MesoNet/data9.txt

# %%
# !head results/$NAME/data9.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg,0.7093555
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg,0.03512901
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg,0.9490967
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172214491.jpg,0.1739943
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595163091432.jpg,0.9269047
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172052975.jpg,0.9745301
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595160634105.jpg,0.988913
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595162814107.jpg,0.99798274
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595171119134.jpg,0.980072
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595173531575.jpg,0.60957897
