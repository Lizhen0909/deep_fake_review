# %%
import os,sys

# %%
files1=!find  `pwd`/data/DFGC-2021-crop/ -name \*.jpg 
files2=!find `pwd`/data/DFGC-2021-crop/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 18000

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg']

# %%
with open('/tmp/inputlist_Capsule-Forensics-v2', 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_Capsule-Forensics-v2
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg

# %%
# !mkdir -p results/Capsule-Forensics-v2

# %%
# %%time
# !cd Capsule-Forensics-v2 && \
PYTHONPATH=. conda run -n Capsule-Forensics-v2 \
python  ../Capsule-Forensics-v2_test_binary_ffpp.py \
-i /tmp/inputlist_Capsule-Forensics-v2 \
--output ../results/Capsule-Forensics-v2/dfgc2021.txt
# Out:
# Namespace(batchSize=32, gpu_id=-1, id=21, imageSize=300, input='/tmp/inputlist_Capsule-Forensics-v2', outf='checkpoints/binary_faceforensicspp', output='../results/Capsule-Forensics-v2/dfgc2021.txt', random=False, workers=4)
# num of images= 18000
# [Epoch 21] Test acc: 77.72   EER: 0.00
#
# 100%|██████████| 563/563 [15:50<00:00,  1.69s/it]
# /global/home/users/lizhen/.local/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# CPU times: user 16 s, sys: 2.63 s, total: 18.7 s
# Wall time: 16min 4s

# %%
# !wc -l  results/Capsule-Forensics-v2/dfgc2021.txt
# Out:
# 18000 results/Capsule-Forensics-v2/dfgc2021.txt

# %%
# !head results/Capsule-Forensics-v2/dfgc2021.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg,0.000000,0.386576
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg,0.000000,0.386544
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg,0.000000,0.386527
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id3_0006_00060.jpg,1.000000,0.613411
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id20_0009_00000.jpg,0.000000,0.386561
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id13_id10_0005_00120.jpg,1.000000,0.613405
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id23_0007_00120.jpg,0.000000,0.386552
# ...
