# %%
import os,sys

# %%
files1=!find  `pwd`/data/data9/ -name \*.jpg 
files2=!find `pwd`/data/data9/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 74337

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg']

# %%
NAME='adversarial_deepfakes'

# %%
with open('/tmp/inputlist_{}'.format(NAME), 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_$NAME
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg

# %%
# !mkdir -p results/$NAME

# %%
# %%time
ENVNAME='CNNDetection'
# !cd $NAME && \
PYTHONPATH=.:utils conda run -n $ENVNAME \
python  ../run_adversarial_deepfakes.py \
-i /tmp/inputlist_$NAME \
--output ../results/$NAME/data9.txt \
# Out:
# class <module 'utils.HHReLU' from '/global/home/users/lizhen/mydev/deep_fake_review/adversarial_deepfakes/utils/HHReLU.py'>
# num of images= 74337
# Evaluating model: resnet_blur.pt
#
#   0%|          | 0/1162 [00:00<?, ?it/s]/global/home/users/lizhen/mydev/deep_fake_review/adversarial_deepfakes/utils/HHReLU.py:34: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   x.add_(-0.5 * d, q)
# /global/home/users/lizhen/.conda/envs/CNNDetection/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 100%|██████████| 1162/1162 [3:22:06<00:00, 10.44s/it]
# CPU times: user 3min 5s, sys: 29.7 s, total: 3min 34s
# Wall time: 3h 23min 40s

# %%
# !wc -l  results/$NAME/data9.txt
# Out:
# 74337 results/adversarial_deepfakes/data9.txt

# %%
# !head results/$NAME/data9.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg,0.3537,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg,0.4943,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg,0.2409,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172214491.jpg,0.0583,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595163091432.jpg,0.4957,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172052975.jpg,0.6150,1.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595160634105.jpg,0.5497,1.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595162814107.jpg,0.0167,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595171119134.jpg,0.6405,1.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595173531575.jpg,0.8061,1.0
