# %%
import os,sys

# %%
files1=!find  `pwd`/data/data9/ -name \*.jpg 
files2=!find `pwd`/data/data9/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 74337

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg']

# %%
with open('/tmp/inputlist_ClassNSeg', 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_ClassNSeg
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg

# %%
# !mkdir -p results/ClassNSeg

# %%
# %%time
# !cd ClassNSeg && \
PYTHONPATH=. conda run -n Capsule-Forensics-v2 \
python  ../ClassNSeg_test_cls.py \
-i /tmp/inputlist_ClassNSeg \
--output ../results/ClassNSeg/data9.txt
# Out:
# Namespace(batchSize=64, gpu_id=-1, id=46, imageSize=256, input='/tmp/inputlist_ClassNSeg', outf='checkpoints/full', output='../results/ClassNSeg/data9.txt', workers=4)
# num of images= 74337
# [Epoch 46] act_loss: 1.1946  acc: 18.93   eer: 0.00
# 100%|██████████| 1162/1162 [09:42<00:00,  2.00it/s]
# /global/home/users/lizhen/.local/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# CPU times: user 10.4 s, sys: 1.53 s, total: 11.9 s
# Wall time: 10min 48s

# %%
# !wc -l  results/ClassNSeg/data9.txt
# Out:
# 74337 results/ClassNSeg/data9.txt

# %%
# !head results/ClassNSeg/data9.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg,1.000000,0.508359
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg,1.000000,0.531632
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg,0.000000,0.495770
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172214491.jpg,1.000000,0.500262
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595163091432.jpg,1.000000,0.504378
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172052975.jpg,1.000000,0.506547
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595160634105.jpg,0.000000,0.499243
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595162814107.jpg,0.000000,0.493305
# ...
