# %%
import os,sys

# %%
files1=!find  `pwd`/data/DFGC-2021-crop/ -name \*.jpg 
files2=!find `pwd`/data/DFGC-2021-crop/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 18000

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg']

# %%
NAME='CNNDetection'

# %%
with open('/tmp/inputlist_{}'.format(NAME), 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_$NAME
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg

# %%
# !mkdir -p results/$NAME

# %%
# %%time
# !cd $NAME && \
PYTHONPATH=. conda run -n $NAME \
python  ../run_CNNDetection.py \
-i /tmp/inputlist_$NAME \
--output ../results/$NAME/dfgc2021.txt \
--use_cpu
# Out:
# Not cropping
# num of images= 18000
#
#   0%|          | 0/563 [00:00<?, ?it/s]/global/home/users/lizhen/.conda/envs/CNNDetection/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 100%|██████████| 563/563 [12:09<00:00,  1.30s/it]
# CPU times: user 12.9 s, sys: 2.1 s, total: 15 s
# Wall time: 12min 19s

# %%
# !wc -l  results/$NAME/dfgc2021.txt
# Out:
# 18000 results/CNNDetection/dfgc2021.txt

# %%
# !head results/$NAME/dfgc2021.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg,0.0002
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg,0.0002
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id3_0006_00060.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id20_0009_00000.jpg,0.0165
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id13_id10_0005_00120.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id23_0007_00120.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id20_0002_00060.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id0_id16_0003_00120.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id21_0005_00120.jpg,0.0000
