# %%
import os,sys

# %%
files1=!find  `pwd`/data/data9/ -name \*.jpg 
files2=!find `pwd`/data/data9/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 74337

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg']

# %%
with open('/tmp/inputlist_Capsule-Forensics-v2', 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_Capsule-Forensics-v2
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg

# %%
# !mkdir -p results/Capsule-Forensics-v2

# %%
# %%time
# !cd Capsule-Forensics-v2 && \
PYTHONPATH=. conda run -n Capsule-Forensics-v2 \
python  ../Capsule-Forensics-v2_test_binary_ffpp.py \
-i /tmp/inputlist_Capsule-Forensics-v2 \
--output ../results/Capsule-Forensics-v2/data9.txt
# Out:
# Namespace(batchSize=32, gpu_id=-1, id=21, imageSize=300, input='/tmp/inputlist_Capsule-Forensics-v2', outf='checkpoints/binary_faceforensicspp', output='../results/Capsule-Forensics-v2/data9.txt', random=False, workers=4)
# num of images= 74337
# [Epoch 21] Test acc: 30.26   EER: 0.00
# 100%|██████████| 2324/2324 [1:16:32<00:00,  1.98s/it]
# /global/home/users/lizhen/.local/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# CPU times: user 1min 22s, sys: 14.2 s, total: 1min 36s
# Wall time: 1h 18min 1s

# %%
# !wc -l  results/Capsule-Forensics-v2/data9.txt
# Out:
# 74337 results/Capsule-Forensics-v2/data9.txt

# %%
# !head results/Capsule-Forensics-v2/data9.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg,1.000000,0.612821
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg,1.000000,0.613450
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg,1.000000,0.613447
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172214491.jpg,1.000000,0.613477
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595163091432.jpg,1.000000,0.613448
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172052975.jpg,1.000000,0.613482
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595160634105.jpg,1.000000,0.613431
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595162814107.jpg,1.000000,0.613378
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595171119134.jpg,1.000000,0.613460
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595173531575.jpg,1.000000,0.613471
