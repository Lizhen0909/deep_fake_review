# %%
import os,sys

# %%
files1=!find  `pwd`/data/DFGC-2021-crop/ -name \*.jpg 
files2=!find `pwd`/data/DFGC-2021-crop/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 18000

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg']

# %%
NAME='adversarial_deepfakes'

# %%
with open('/tmp/inputlist_{}'.format(NAME), 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_$NAME
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg

# %%
# !mkdir -p results/$NAME

# %%
# %%time
ENVNAME='CNNDetection'
# !cd $NAME && \
PYTHONPATH=.:utils conda run -n $ENVNAME \
python  ../run_adversarial_deepfakes.py \
-i /tmp/inputlist_$NAME \
--output ../results/$NAME/dfgc2021.txt \
# Out:
# class <module 'utils.HHReLU' from '/global/home/users/lizhen/mydev/deep_fake_review/adversarial_deepfakes/utils/HHReLU.py'>
# num of images= 18000
# Evaluating model: resnet_blur.pt
#
#   0%|          | 0/282 [00:00<?, ?it/s]/global/home/users/lizhen/mydev/deep_fake_review/adversarial_deepfakes/utils/HHReLU.py:34: UserWarning: This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha) (Triggered internally at  /pytorch/torch/csrc/utils/python_arg_parser.cpp:1025.)
#   x.add_(-0.5 * d, q)
# /global/home/users/lizhen/.conda/envs/CNNDetection/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 100%|██████████| 282/282 [26:32<00:00,  5.65s/it]
# CPU times: user 25.8 s, sys: 4.36 s, total: 30.1 s
# Wall time: 26min 46s

# %%
# !wc -l  results/$NAME/dfgc2021.txt
# Out:
# 18000 results/adversarial_deepfakes/dfgc2021.txt

# %%
# !head results/$NAME/dfgc2021.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg,0.8419,1.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg,0.8525,1.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg,0.2809,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id3_0006_00060.jpg,0.6535,1.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id20_0009_00000.jpg,0.2570,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id13_id10_0005_00120.jpg,0.0121,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id23_0007_00120.jpg,0.0017,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id20_0002_00060.jpg,0.3247,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id0_id16_0003_00120.jpg,0.0015,0.0
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id21_0005_00120.jpg,0.0548,0.0
