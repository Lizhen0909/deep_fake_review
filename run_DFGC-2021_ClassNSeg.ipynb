# %%
import os,sys

# %%
files1=!find  `pwd`/data/DFGC-2021-crop/ -name \*.jpg 
files2=!find `pwd`/data/DFGC-2021-crop/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 18000

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg']

# %%
with open('/tmp/inputlist_ClassNSeg', 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_ClassNSeg
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg

# %%
# !mkdir -p results/ClassNSeg

# %%
# %%time
# !cd ClassNSeg && \
PYTHONPATH=. conda run -n Capsule-Forensics-v2 \
python  ../ClassNSeg_test_cls.py \
-i /tmp/inputlist_ClassNSeg \
--output ../results/ClassNSeg/dfgc2021.txt
# Out:
# Namespace(batchSize=64, gpu_id=-1, id=46, imageSize=256, input='/tmp/inputlist_ClassNSeg', outf='checkpoints/full', output='../results/ClassNSeg/dfgc2021.txt', workers=4)
# num of images= 18000
# [Epoch 46] act_loss: 1.6643  acc: 7.84   eer: 0.00
#
# 100%|██████████| 282/282 [02:10<00:00,  2.16it/s]
# /global/home/users/lizhen/.local/lib/python3.7/site-packages/sklearn/metrics/_ranking.py:951: UndefinedMetricWarning: No positive samples in y_true, true positive value should be meaningless
#   UndefinedMetricWarning)
# CPU times: user 2.04 s, sys: 352 ms, total: 2.39 s
# Wall time: 2min 17s

# %%
# !wc -l  results/ClassNSeg/dfgc2021.txt
# Out:
# 18000 results/ClassNSeg/dfgc2021.txt

# %%
# !head results/ClassNSeg/dfgc2021.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id26_0004_00060.jpg,1.000000,0.711957
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id28_id0_0009_00120.jpg,1.000000,0.641672
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id9_id6_0005_00060.jpg,1.000000,0.754900
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id3_0006_00060.jpg,1.000000,0.701299
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id24_id20_0009_00000.jpg,1.000000,0.655542
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id13_id10_0005_00120.jpg,0.000000,0.429700
# /global/home/users/lizhen/mydev/deep_fake_review/data/DFGC-2021-crop/yZzzzzz_849853/id30_id23_0007_00120.jpg,1.000000,0.710389
# ...
