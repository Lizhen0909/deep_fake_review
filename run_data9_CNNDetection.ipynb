# %%
import os,sys

# %%
files1=!find  `pwd`/data/data9/ -name \*.jpg 
files2=!find `pwd`/data/data9/ -name \*.png 
files=files1+files2

# %%
len(files)
# Out:
# 74337

# %%
files[:3]
# Out:
# ['/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg',
#  '/global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg']

# %%
NAME='CNNDetection'

# %%
with open('/tmp/inputlist_{}'.format(NAME), 'wt') as f:
    f.write("\n".join(files))

# %%
# !head -n 3 /tmp/inputlist_$NAME
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg

# %%
# !mkdir -p results/$NAME

# %%
# %%time
# !cd $NAME && \
PYTHONPATH=. conda run -n $NAME \
python  ../run_CNNDetection.py \
-i /tmp/inputlist_$NAME \
--output ../results/$NAME/data9.txt \
--use_cpu
# Out:
# Not cropping
# num of images= 74337
#
#   0%|          | 0/2324 [00:00<?, ?it/s]/global/home/users/lizhen/.conda/envs/CNNDetection/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# 100%|██████████| 2324/2324 [51:44<00:00,  1.34s/it]
# CPU times: user 51.8 s, sys: 8.52 s, total: 1min
# Wall time: 52min 12s

# %%
# !wc -l  results/$NAME/data9.txt
# Out:
# 74337 results/CNNDetection/data9.txt

# %%
# !head results/$NAME/data9.txt
# Out:
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172258325.jpg,0.0008
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595169655304.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595153374933.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172214491.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595163091432.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595172052975.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595160634105.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595162814107.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595171119134.jpg,0.0000
# /global/home/users/lizhen/mydev/deep_fake_review/data/data9/faceapp/FaceApp_1595173531575.jpg,0.0002
